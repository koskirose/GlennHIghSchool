# %%
#Import the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

stoplight_colors = ["#FF8C00","#0000FF",'#008000','#FFFF00','#DC143C' ]
sns.set_palette(sns.color_palette(stoplight_colors))

# %%
#data import
glenn = pd.read_csv("Glenn.csv")
glenn.head()
# Out:
#    Grade    April      May         Title Department  Course  Section  \
# 0   10.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 1   11.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 2   12.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 3   11.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 4   11.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
#
#                     Teacher  Bldg_Course  Bldg_Student  ...  Unnamed: 14  \
# 0  Anagnos, Alexander 20549          6.0           6.0  ...          NaN
# 1  Anagnos, Alexander 20549          6.0           6.0  ...          NaN
# 2  Anagnos, Alexander 20549          6.0           6.0  ...          NaN
# 3  Anagnos, Alexander 20549          6.0           6.0  ...          NaN
# 4  Anagnos, Alexander 20549          6.0           6.0  ...          NaN
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# ...

# %%
glenn = glenn.iloc[:,0:10]
glenn.head()
# Out:
#    Grade    April      May         Title Department  Course  Section  \
# 0   10.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 1   11.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 2   12.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 3   11.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
# 4   11.0  Engaged  Engaged  U.S. History         SS  4310-B      3.0
#
#                     Teacher  Bldg_Course  Bldg_Student
# 0  Anagnos, Alexander 20549          6.0           6.0
# 1  Anagnos, Alexander 20549          6.0           6.0
# 2  Anagnos, Alexander 20549          6.0           6.0
# 3  Anagnos, Alexander 20549          6.0           6.0
# 4  Anagnos, Alexander 20549          6.0           6.0

# %%
sns.countplot("April", data=glenn)
plt.title("All Glenn, March-April 30", fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [73,22,5]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color,autopct='%1.1f%%')
ax1.axis('equal')
plt.title("All Glenn, March-April 30", fontsize=20)
plt.show()

# %%
glenn["April"].value_counts()
# Out:
# Engaged            5031
# Unengaged          1555
# Not Contactable     332
# Name: April, dtype: int64

# %%
sns.countplot("May", data=glenn, order=["Engaged","Unengaged","Not Contactable"])
plt.title("All Glenn, May", fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [76,20,4]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("All Glenn, May" ,fontsize=20)
plt.show()

# %%
glenn["May"].value_counts()
# Out:
# Engaged            5239
# Unengaged          1386
# Not Contactable     293
# Name: May, dtype: int64

# %%
sns.countplot('Grade', data=glenn)
plt.title("Grade Level Totals \n each student is entered more than once \n seniors have off periods")
plt.show()

# %%
glenn['Grade'].value_counts()
# Out:
# 9.0     1808
# 10.0    1804
# 11.0    1792
# 12.0    1514
# Name: Grade, dtype: int64

# %%
sns.countplot("April", data=glenn, hue="Grade").set_title("By Grade Level March- April", fontsize=20)
plt.show()

# %%
glenn.groupby(by=["Grade","April"]).size()
# Out:
# Grade  April
# 9.0    Engaged            1419
#        Not Contactable      53
#        Unengaged           336
# 10.0   Engaged            1246
#        Not Contactable     123
#        Unengaged           435
# 11.0   Engaged            1292
#        Not Contactable     118
#        Unengaged           382
# 12.0   Engaged            1074
#        Not Contactable      38
#        Unengaged           402
# dtype: int64

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [78,19,3]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("9th Grade March-April" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [69,24,7]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("10th Grade March-April" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [72,21,7]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("11th Grade March-April" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [71,27,2]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("12th Grade March-April" ,fontsize=20)
plt.show()

# %%
sns.countplot("May", data=glenn, hue="Grade",order=["Engaged","Unengaged","Not Contactable"]).set_title("By Grade Level-May", fontsize=20)

plt.show()

# %%
glenn.groupby(by=["Grade","May"]).size()
# Out:
# (Grade  May
#  9.0    Engaged            1465
#         Not Contactable      60
#         Unengaged           283
#  10.0   Engaged            1331
#         Not Contactable     106
#         Unengaged           367
#  11.0   Engaged            1270
#         Not Contactable     103
#         Unengaged           419
#  12.0   Engaged            1173
#         Not Contactable      24
#         Unengaged           317
#  dtype: int64,
#  6918)

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [74,20,6]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("10th Grade May" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [81,16,3]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("9th Grade May" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes = [71,23,6]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("11th Grade May" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 77,21,2]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("12th Grade May" ,fontsize=20)
plt.show()

# %%
sns.countplot("Department", data=glenn)
plt.title("Count by Departments")
plt.show()

# %%
glenn["Department"].value_counts()
# Out:
# SS      1757
# SCI     1743
# ELA     1716
# MATH    1702
# Name: Department, dtype: int64

# %%
sns.countplot("April", data=glenn, hue="Department").set_title("Beginning of Covid through April 30", fontsize=30)
plt.show()

# %%
glenn.groupby(by=["Department","April"] ).size()
# Out:
# Department  April
# ELA         Engaged            1122
#             Not Contactable      94
#             Unengaged           500
# MATH        Engaged            1411
#             Not Contactable      71
#             Unengaged           220
# SCI         Engaged            1200
#             Not Contactable     142
#             Unengaged           401
# SS          Engaged            1298
#             Not Contactable      25
#             Unengaged           434
# dtype: int64

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 65,29,6]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("ELA April" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 83,13,4]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("MATH April" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 69,23,8]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("SCIENCE April" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 74,25,1]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("SOCIAL STUDIES April" ,fontsize=20)
plt.show()

# %%
sns.countplot("April", data=glenn, hue="Department").set_title("End Covid Month of May", fontsize=30)
plt.show()

# %%
glenn.groupby(by=["Department","May"] ).size()
# Out:
# Department  May
# ELA         Engaged            1312
#             Not Contactable      86
#             Unengaged           318
# MATH        Engaged            1372
#             Not Contactable      50
#             Unengaged           280
# SCI         Engaged            1232
#             Not Contactable     134
#             Unengaged           377
# SS          Engaged            1323
#             Not Contactable      23
#             Unengaged           411
# dtype: int64

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 76,19,5]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("ELA May" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 81,16,3]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("MATH May" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 71,22,7]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("SCIENCE May" ,fontsize=20)
plt.show()

# %%
label="Engaged",'Unengaged','Not Contactable'
sizes =[ 75,23,2]
color=["C0","C1","C2"]
fig1, ax1=plt.subplots()
ax1.pie(sizes, labels=label, colors=color, autopct='%1.1f%%')
ax1.axis('equal')
plt.title("SOCIAL STUDIES May" ,fontsize=20)
plt.show()

# %%
math = glenn[(glenn["Department"]=="MATH")]
social = glenn[(glenn["Department"]=="SS")]
science = glenn[(glenn["Department"]=="SCI")]
english = glenn[(glenn["Department"]=="ELA")]
grade9 = glenn[(glenn["Grade"]==9)]
grade10 = glenn[(glenn["Grade"]==10)]
grade11 = glenn[(glenn["Grade"]==11)]
grade12 = glenn[(glenn["Grade"]==12)]

# %%
glenn.dtypes
# Out:
# Grade           float64
# April            object
# May              object
# Title            object
# Department       object
# Course           object
# Section         float64
# Teacher          object
# Bldg_Course     float64
# Bldg_Student    float64
# dtype: object

# %%
a=math.groupby(by=["Teacher", "April"]).size()
b=math.groupby(by=["Teacher", "May"]).size()
pd.concat([a,b], axis=1, keys=["April","May"])
# Out:
#                                             April    May
# Bamber, Brittany 19486     Engaged            119  127.0
#                            Unengaged           16    8.0
# Blakeney, Callie 4402      Engaged              9   12.0
#                            Unengaged            4    1.0
# Buckly, Stephanie 19556    Engaged            130  119.0
#                            Not Contactable     23   14.0
#                            Unengaged           11   31.0
# Butler, Ian 17447          Engaged             70   67.0
#                            Not Contactable      1    1.0
#                            Unengaged           27   30.0
# Cherry, Cassandra 16004    Engaged              9    9.0
# Ellis, Christina 20957     Engaged            110  101.0
#                            Not Contactable     16   13.0
#                            Unengaged           17   29.0
# Gaitan, Jessica 21498      Engaged             78   63.0
# ...

# %%
math.pivot_table('April','Teacher', aggfunc=np.count_nonzero, margins=True)
# Out:
#                             April
# Teacher
# Bamber, Brittany 19486        135
# Blakeney, Callie 4402          13
# Buckly, Stephanie 19556       164
# Butler, Ian 17447              98
# Cherry, Cassandra 16004         9
# Ellis, Christina 20957        143
# Gaitan, Jessica 21498          81
# Guzman, Marissa 17633          97
# Kennedy, Danielle 19537       144
# Koski, Sherri 19087           127
# Krauskopf, Stephanie 16788    108
# Lane, Kimberly 19027          121
# Mahoney, Suzy 10603            16
# Mckinney, Sandra 19461          4
# Mullens, Deanne 7585           12
# Ortiz, Jonathan 19391         100
# Ruppert, Susanna 20955        151
# Weir, Kelsey 18527            157
# Wilson, Aaron 15432            22
# All                          1702

# %%
table = pd.pivot_table(math, index=["Teacher", "April"] ,aggfunc=[np.count_nonzero])

# %%
table.head()
# Out:
#                                   count_nonzero                      \
#                                     Bldg_Course Bldg_Student Course
# Teacher                 April
# Bamber, Brittany 19486  Engaged           119.0        119.0    119
#                         Unengaged          16.0         16.0     16
# Blakeney, Callie 4402   Engaged             9.0          9.0      9
#                         Unengaged           4.0          4.0      4
# Buckly, Stephanie 19556 Engaged           130.0        130.0    130
#
#
#                                   Department  Grade  May Section Title
# Teacher                 April
# Bamber, Brittany 19486  Engaged          119  119.0  119   119.0   119
#                         Unengaged         16   16.0   16    16.0    16
# Blakeney, Callie 4402   Engaged            9    9.0    9     9.0     9
#                         Unengaged          4    4.0    4     4.0     4
# Buckly, Stephanie 19556 Engaged          130  130.0  130   130.0   130
